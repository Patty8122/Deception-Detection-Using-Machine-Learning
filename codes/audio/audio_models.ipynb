# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# %cd MyDrive/
# %cd result_files
import pandas as pd
# Out:
# Mounted at /gdrive
# /gdrive
# /gdrive/MyDrive
# /gdrive/MyDrive/result_files

# %%
df = pd.read_csv('usable_audio_features.csv')
gender = pd.read_csv('personality_y.csv')
df  = pd.merge(df,gender,how='outer',left_on='id',right_on='person_id')
# df.drop('person_id',axis=1,inplace=True)

df = df[df.columns[list(range(6378))]]

# %%
df
# Out:
#      audspec_lengthL1norm_sma_range  ...  Gender_Male
# 0                          4.861600  ...            1
# 1                          4.939749  ...            1
# 2                          5.231193  ...            1
# 3                          5.161312  ...            1
# 4                          4.790831  ...            1
# ..                              ...  ...          ...
# 892                        3.992145  ...            0
# 893                        5.317191  ...            0
# 894                        4.721120  ...            0
# 895                        5.083996  ...            0
# 896                        4.199941  ...            0
#
# [897 rows x 6378 columns]

# %%
df3= pd.read_csv('liwc_final_question_type.csv')

# %%
df3.columns
# Out:
# Index(['Source (D)', 'question', 'person_id', 'WC', 'Analytic', 'Clout',
#        'Authentic', 'Tone', 'WPS', 'Sixltr', 'Dic', 'function', 'pronoun',
#        'ppron', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep',
#        'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare',
#        'interrog', 'number', 'quant', 'affect', 'posemo', 'negemo', 'anx',
#        'anger', 'sad', 'social', 'family', 'friend', 'female', 'male',
#        'cogproc', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'percept', 'see', 'hear', 'feel', 'bio', 'body', 'health', 'sexual',
#        'ingest', 'drives', 'affiliation', 'achieve', 'power', 'reward', 'risk',
#        'focuspast', 'focuspresent', 'focusfuture', 'relativ', 'motion',
#        'space', 'time', 'work', 'leisure', 'home', 'money', 'relig', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler',
#        'AllPunc', 'Period', 'Comma', 'Colon', 'QMark', 'Dash', 'Apostro',
#        'OtherP', 'y', 'positive_assumption', 'negative_assumption',
#        'outcome_question', 'recollection_question', 'hypothetical_question'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['audspec_lengthL1norm_sma_range', 'audspec_lengthL1norm_sma_maxPos',
#        'audspec_lengthL1norm_sma_minPos', 'audspec_lengthL1norm_sma_quartile1',
#        'audspec_lengthL1norm_sma_quartile2',
#        'audspec_lengthL1norm_sma_quartile3', 'audspec_lengthL1norm_sma_iqr1-2',
#        'audspec_lengthL1norm_sma_iqr2-3', 'audspec_lengthL1norm_sma_iqr1-3',
#        'audspec_lengthL1norm_sma_percentile1.0',
#        ...
#        'mfcc_sma_de[14]_minRangeRel', 'mfcc_sma_de[14]_meanRisingSlope',
#        'mfcc_sma_de[14]_stddevRisingSlope', 'mfcc_sma_de[14]_meanFallingSlope',
#        'mfcc_sma_de[14]_stddevFallingSlope', 'id', 'y', 'person_id',
#        'What is your age (in years) ?', 'Gender_Male'],
#       dtype='object', length=6378)

# %%
df3 = df3[['question','person_id','positive_assumption', 'negative_assumption','outcome_question', 'recollection_question', 'hypothetical_question']]

# %%
df.reset_index(inplace=True)
df3.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df3.drop('index',axis=1,inplace=True)

# df.drop('person_id',axis=1,inplace=True)

# %%
df  = pd.concat([df,df3],axis=1)

df
# Out:
#      audspec_lengthL1norm_sma_range  ...  hypothetical_question
# 0                          4.861600  ...                      0
# 1                          4.939749  ...                      0
# 2                          5.231193  ...                      0
# 3                          5.161312  ...                      0
# 4                          4.790831  ...                      0
# ..                              ...  ...                    ...
# 892                        3.992145  ...                      0
# 893                        5.317191  ...                      0
# 894                        4.721120  ...                      0
# 895                        5.083996  ...                      0
# 896                        4.199941  ...                      0
#
# [897 rows x 6385 columns]

# %%
df.drop('person_id',axis=1,inplace=True)

# %%
df.drop('question',axis=1,inplace=True)

# %%
import random
random.seed(0)
samples= list(df.id.unique())
num_samples = len(samples)
train_ids = random.sample(samples,round(0.9*num_samples))
test_ids = list(set(samples)-set(train_ids))

df_train=pd.DataFrame()
for i in train_ids:
  df_train=df_train.append(df[df['id']==i])

df_test=pd.DataFrame()
for i in test_ids:
  df_test=df_test.append(df[df['id']==i])

X_train = df_train.drop('y',axis=1)
X_test = df_test.drop('y',axis=1)
y_train = df_train['y']
y_test = df_test['y']

# %%
df.drop('id',axis=1,inplace=True)

# %%
# den = X_train.groupby('Gender_Male')[col_transform].transform(sum)
# X_train[col_transform] /= den
# X_test[col_transform] /= den

# %%
X_test = X_test.reset_index()
X_train = X_train.reset_index()

# %%
from sklearn.preprocessing import StandardScaler
col_transform =list(X_train.columns)
col_transform.remove('id')
col_transform.remove('Gender_Male')
scale = StandardScaler().fit(X_train[col_transform])
X_train[col_transform] = pd.DataFrame(scale.transform(X_train[col_transform]),columns=col_transform)
# X_test = scale.transform(X_test)

# %%
X_test[col_transform] = pd.DataFrame(scale.transform(X_test[col_transform]),columns=col_transform)

# %%
df_train = X_train.copy()
df_train['y'] = y_train.copy()

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### null importance

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import time
from lightgbm import LGBMClassifier
import lightgbm as lgb

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
# %matplotlib inline

import warnings
warnings.simplefilter('ignore', UserWarning)

import gc
gc.enable()

# %%
data = df_train.copy()



# categorical_feats = df_train.columns[[-1,-2,-3]]

# print(categorical_feats)
# for f_ in categorical_feats:
#     data[f_], _ = pd.factorize(data[f_])
#     # Set feature type as categorical
#     data[f_] = data[f_].astype('category')

# %%
data
# Out:
#         timestamp  confidence  gaze_0_x  gaze_0_y  gaze_0_z  gaze_1_x  \
# 6415     0.000000        0.98  0.326309  0.274022 -0.904674  0.158873
# 6416     0.040000        0.98  0.336460  0.274016 -0.900949  0.161493
# 6417     0.080000        0.98  0.341593  0.269892 -0.900263  0.166425
# 6418     0.120000        0.98  0.341751  0.269591 -0.900292  0.166547
# 6419     0.160000        0.98  0.341803  0.269438 -0.900319  0.166416
# ...           ...         ...       ...       ...       ...       ...
# 860059  44.320000        0.98  0.191839  0.410695 -0.891362  0.040223
# 860060  44.360001        0.98  0.189389  0.405606 -0.894212  0.039152
# 860061  44.400002        0.98  0.187418  0.443895 -0.876260  0.030524
# 860062  44.439999        0.93  0.186500  0.458894 -0.868697  0.029780
# 860063  44.480000        0.98  0.185974  0.464983 -0.865566  0.025003
#
#         gaze_1_y  gaze_1_z  gaze_angle_x  gaze_angle_y  ...  AU26_c  AU28_c  \
# 6415    0.243419 -0.956821         0.255         0.271  ...       0       0
# 6416    0.241291 -0.956922         0.262         0.271  ...       0       0
# 6417    0.237461 -0.957035         0.267         0.267  ...       0       0
# 6418    0.237231 -0.957070         0.267         0.266  ...       0       0
# 6419    0.237016 -0.957146         0.267         0.266  ...       0       0
# ...          ...       ...           ...           ...  ...     ...     ...
# 860059  0.424845 -0.904372         0.129         0.435  ...       1       0
# 860060  0.419084 -0.907103         0.126         0.429  ...       1       0
# 860061  0.459217 -0.887799         0.123         0.473  ...       0       0
# 860062  0.475174 -0.879388         0.123         0.491  ...       0       0
# 860063  0.481289 -0.876205         0.121         0.498  ...       0       0
#
#         AU45_c  question  person_id   WC  OtherP  y  positive_assumption  \
# 6415         0         1         28  119     0.0  0                    0
# 6416         0         1         28  119     0.0  0                    0
# 6417         0         1         28  119     0.0  0                    0
# 6418         0         1         28  119     0.0  0                    0
# 6419         0         1         28  119     0.0  0                    0
# ...        ...       ...        ...  ...     ... ..                  ...
# 860059       0        24         24  100     0.0  1                    0
# 860060       0        24         24  100     0.0  1                    0
# 860061       0        24         24  100     0.0  1                    0
# 860062       0        24         24  100     0.0  1                    0
# 860063       0        24         24  100     0.0  1                    0
#
#         negative_assumption
# 6415                      0
# 6416                      0
# 6417                      0
# 6418                      0
# 6419                      0
# ...                     ...
# 860059                    0
# 860060                    0
# 860061                    0
# 860062                    0
# 860063                    0
#
# [787477 rows x 718 columns]

# %%
def get_feature_importances(data, shuffle, seed=None):
    # Gather real features
    train_features = [f for f in data if f not in ['y', 'question','WC','positive_assumption','negative_assumption']]
    # Go over fold and keep track of CV score (train and valid) and feature importances
    
    # Shuffle target if required
    y = data['y'].copy()
    if shuffle:
        # Here you could as well use a binomial distribution
        y = data['y'].copy().sample(frac=1.0)
    
    # Fit LightGBM in RF mode, yes it's quicker than sklearn RandomForest
    dtrain = lgb.Dataset(data[train_features], y, free_raw_data=False, silent=True)
    lgb_params = {
        'objective': 'binary',
        'boosting_type': 'rf',
        'subsample': 0.623,
        'colsample_bytree': 0.7,
        'num_leaves': 127,
        'max_depth': 8,
        'seed': seed,
        'bagging_freq': 1,
        'n_jobs': 4
    }
    
    # Fit the model
    clf = lgb.train(params=lgb_params, train_set=dtrain, num_boost_round=200)

    # Get feature importances
    imp_df = pd.DataFrame()
    imp_df["feature"] = list(train_features)
    imp_df["importance_gain"] = clf.feature_importance(importance_type='gain')
    imp_df["importance_split"] = clf.feature_importance(importance_type='split')
    imp_df['trn_score'] = roc_auc_score(y, clf.predict(data[train_features]))
    
    return imp_df

# %%
np.random.seed(123)
# Get the actual importance, i.e. without shuffling
actual_imp_df = get_feature_importances(data=data, shuffle=False)
# Out:
# [LightGBM] [Info] Number of positive: 421357, number of negative: 366120
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.064860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176490
# [LightGBM] [Info] Number of data points in the train set: 787477, number of used features: 713
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.535072 -> initscore=0.140519
# [LightGBM] [Info] Start training from score 0.140519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
actual_imp_df.trn_score.unique()
# Out:
# array([0.72580373])

# %%
null_imp_df = pd.DataFrame()
nb_runs = 80
import time
start = time.time()
dsp = ''
for i in range(nb_runs):
    # Get current run importances
    imp_df = get_feature_importances(data=data, shuffle=True)
    imp_df['run'] = i + 1 
    # Concat the latest importances with the old ones
    null_imp_df = pd.concat([null_imp_df, imp_df], axis=0)
    # Erase previous message
    for l in range(len(dsp)):
        print('\b', end='', flush=True)
    # Display current run and time used
    spent = (time.time() - start) / 60
    dsp = 'Done with %4d of %4d (Spent %5.1f min)' % (i + 1, nb_runs, spent)
    print(dsp, end='', flush=True)
# Out:
# [LightGBM] [Info] Number of positive: 421357, number of negative: 366120
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.049123 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176490
# [LightGBM] [Info] Number of data points in the train set: 787477, number of used features: 713
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.535072 -> initscore=0.140519
# [LightGBM] [Info] Start training from score 0.140519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Done with    1 of   80 (Spent   1.4 min)[LightGBM] [Info] Number of positive: 421357, number of negative: 366120
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.087780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176490
# [LightGBM] [Info] Number of data points in the train set: 787477, number of used features: 713
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.535072 -> initscore=0.140519
# [LightGBM] [Info] Start training from score 0.140519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Done with    2 of   80 (Spent   2.7 min)[LightGBM] [Info] Number of positive: 421357, number of negative: 366120
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.140765 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176490
# [LightGBM] [Info] Number of data points in the train set: 787477, number of used features: 713
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.535072 -> initscore=0.140519
# [LightGBM] [Info] Start training from score 0.140519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Done with    3 of   80 (Spent   4.1 min)[LightGBM] [Info] Number of positive: 421357, number of negative: 366120
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.062056 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176490
# [LightGBM] [Info] Number of data points in the train set: 787477, number of used features: 713
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.535072 -> initscore=0.140519
# [LightGBM] [Info] Start training from score 0.140519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Done with    4 of   80 (Spent   5.5 min)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-15ef08f258e3> in <module>
#       6 for i in range(nb_runs):
#       7     # Get current run importances
# ----> 8     imp_df = get_feature_importances(data=data, shuffle=True)
#       9     imp_df['run'] = i + 1
#      10     # Concat the latest importances with the old ones
#
# <ipython-input-27-bea3c00c78bd> in get_feature_importances(data, shuffle, seed)
#      25
#      26     # Fit the model
# ---> 27     clf = lgb.train(params=lgb_params, train_set=dtrain, num_boost_round=200)
#      28
#      29     # Get feature importances
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in construct(self)
#    1466             else:
#    1467                 # create train
# -> 1468                 self._lazy_init(self.data, label=self.label,
#    1469                                 weight=self.weight, group=self.group,
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1268             self.__init_from_csc(data, params_str, ref_dataset)
#    1269         elif isinstance(data, np.ndarray):
# -> 1270             self.__init_from_np2d(data, params_str, ref_dataset)
#    1271         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#    1272             self.__init_from_list_np2d(data, params_str, ref_dataset)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#    1310
#    1311         ptr_data, type_ptr_data, _ = c_float_array(data)
# -> 1312         _safe_call(_LIB.LGBM_DatasetCreateFromMat(
#    1313             ptr_data,
#    1314             ctypes.c_int(type_ptr_data),
#
# KeyboardInterrupt:

# %%
null_imp_df.head()

# %%
def display_distributions(actual_imp_df_, null_imp_df_, feature_):
    plt.figure(figsize=(13, 6))
    gs = gridspec.GridSpec(1, 2)
    # Plot Split importances
    ax = plt.subplot(gs[0, 0])
    a = ax.hist(null_imp_df_.loc[null_imp_df_['feature'] == feature_, 'importance_split'].values, label='Null importances')
    ax.vlines(x=actual_imp_df_.loc[actual_imp_df_['feature'] == feature_, 'importance_split'].mean(), 
               ymin=0, ymax=np.max(a[0]), color='r',linewidth=10, label='Real Target')
    ax.legend()
    ax.set_title('Split Importance of %s' % feature_.upper(), fontweight='bold')
    plt.xlabel('Null Importance (split) Distribution for %s ' % feature_.upper())
    # Plot Gain importances
    ax = plt.subplot(gs[0, 1])
    a = ax.hist(null_imp_df_.loc[null_imp_df_['feature'] == feature_, 'importance_gain'].values, label='Null importances')
    ax.vlines(x=actual_imp_df_.loc[actual_imp_df_['feature'] == feature_, 'importance_gain'].mean(), 
               ymin=0, ymax=np.max(a[0]), color='r',linewidth=10, label='Real Target')
    ax.legend()
    ax.set_title('Gain Importance of %s' % feature_.upper(), fontweight='bold')
    plt.xlabel('Null Importance (gain) Distribution for %s ' % feature_.upper())

# %%
display_distributions(actual_imp_df_=actual_imp_df, null_imp_df_=null_imp_df, feature_='LIVINGAPARTMENTS_AVG')

# %%
feature_scores = []
for _f in actual_imp_df['feature'].unique():
    f_null_imps_gain = null_imp_df.loc[null_imp_df['feature'] == _f, 'importance_gain'].values
    f_act_imps_gain = actual_imp_df.loc[actual_imp_df['feature'] == _f, 'importance_gain'].mean()
    gain_score = np.log(1e-10 + f_act_imps_gain / (1 + np.percentile(f_null_imps_gain, 75)))  # Avoid didvide by zero
    f_null_imps_split = null_imp_df.loc[null_imp_df['feature'] == _f, 'importance_split'].values
    f_act_imps_split = actual_imp_df.loc[actual_imp_df['feature'] == _f, 'importance_split'].mean()
    split_score = np.log(1e-10 + f_act_imps_split / (1 + np.percentile(f_null_imps_split, 75)))  # Avoid didvide by zero
    feature_scores.append((_f, split_score, gain_score))

scores_df = pd.DataFrame(feature_scores, columns=['feature', 'split_score', 'gain_score'])

plt.figure(figsize=(16, 16))
gs = gridspec.GridSpec(1, 2)
# Plot Split importances
ax = plt.subplot(gs[0, 0])
sns.barplot(x='split_score', y='feature', data=scores_df.sort_values('split_score', ascending=False).iloc[0:70], ax=ax)
ax.set_title('Feature scores wrt split importances', fontweight='bold', fontsize=14)
# Plot Gain importances
ax = plt.subplot(gs[0, 1])
sns.barplot(x='gain_score', y='feature', data=scores_df.sort_values('gain_score', ascending=False).iloc[0:70], ax=ax)
ax.set_title('Feature scores wrt gain importances', fontweight='bold', fontsize=14)
plt.tight_layout()

# %% [markdown]
# ### Correlation

# %%
application_sample1 = df_train.loc[df_train.y==1].sample(frac=1, replace=False)
print('label 1 sample size:', str(application_sample1.shape[0]))
application_sample0 = df_train.loc[df_train.y==0].sample(frac=1, replace=False)
print('label 0 sample size:', str(application_sample0.shape[0]))
application = pd.concat([application_sample1, application_sample0], axis=0).sort_values('id')
# Out:
# label 1 sample size: 417
# label 0 sample size: 393

# %%
categorical_list = []
numerical_list = []
for i in application.columns.tolist():
    if application[i].dtype=='object':
        categorical_list.append(i)
    else:
        numerical_list.append(i)
print('Number of categorical features:', str(len(categorical_list)))
print('Number of numerical features:', str(len(numerical_list)))
# Out:
# Number of categorical features: 0
# Number of numerical features: 6382

# %%
# from sklearn.impute import SimpleImputer
# application[numerical_list] = SimpleImputer(strategy='median').fit_transform(application[numerical_list])

# %%
X = application.drop(['y'], axis=1)
y = application.y
feature_name = X.columns.tolist()

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
print(cor_feature)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 100 selected features
# ['pcm_fftMag_spectralFlux_sma_de_percentile1.0', 'pcm_RMSenergy_sma_de_pctlrange0-1', 'pcm_fftMag_spectralHarmonicity_sma_de_pctlrange0-1', 'pcm_fftMag_spectralHarmonicity_sma_iqr2-3', 'pcm_RMSenergy_sma_rqmean', 'mfcc_sma[6]_minSegLen', 'mfcc_sma_de[9]_minSegLen', 'mfcc_sma_de[12]_minSegLen', 'audSpec_Rfilt_sma_de[21]_quartile3', 'audspec_lengthL1norm_sma_qregc3', 'mfcc_sma[14]_meanRisingSlope', 'audSpec_Rfilt_sma_de[20]_quartile3', 'mfcc_sma_de[5]_meanFallingSlope', 'mfcc_sma[14]_minSegLen', 'pcm_fftMag_spectralEntropy_sma_de_kurtosis', 'audSpec_Rfilt_sma_de[18]_segLenStddev', 'pcm_fftMag_spectralHarmonicity_sma_iqr1-3', 'pcm_fftMag_spectralSlope_sma_lpgain', 'pcm_fftMag_spectralHarmonicity_sma_quartile3', 'pcm_fftMag_spectralEntropy_sma_de_meanSegLen', 'pcm_fftMag_spectralEntropy_sma_de_maxSegLen', 'audSpec_Rfilt_sma_de[23]_quartile3', 'mfcc_sma_de[5]_minSegLen', 'mfcc_sma_de[11]_meanRisingSlope', 'pcm_fftMag_spectralFlux_sma_minSegLen', 'jitterLocal_sma_lpc4', 'pcm_RMSenergy_sma_qregc3', 'audspecRasta_lengthL1norm_sma_de_iqr2-3', 'pcm_fftMag_spectralSlope_sma_minSegLen', 'audspec_lengthL1norm_sma_linregc2', 'pcm_fftMag_spectralSlope_sma_de_stddev', 'pcm_fftMag_spectralSlope_sma_de_rqmean', 'pcm_fftMag_spectralFlux_sma_quartile2', 'pcm_fftMag_spectralFlux_sma_iqr1-2', 'audSpec_Rfilt_sma_de[17]_quartile3', 'mfcc_sma[9]_meanRisingSlope', 'mfcc_sma[14]_qregc3', 'audspec_lengthL1norm_sma_de_quartile3', 'pcm_fftMag_spectralHarmonicity_sma_de_iqr1-3', 'pcm_fftMag_spectralHarmonicity_sma_de_percentile1.0', 'mfcc_sma_de[11]_posamean', 'pcm_RMSenergy_sma_amean', 'audspec_lengthL1norm_sma_de_iqr2-3', 'pcm_fftMag_spectralRollOff50.0_sma_linregc2', 'audSpec_Rfilt_sma_de[15]_quartile3', 'mfcc_sma_de[10]_posamean', 'pcm_fftMag_spectralHarmonicity_sma_de_posamean', 'audSpec_Rfilt_sma_de[18]_quartile3', 'audSpec_Rfilt_sma_de[22]_quartile3', 'pcm_fftMag_spectralSlope_sma_de_iqr1-3', 'audspecRasta_lengthL1norm_sma_de_segLenStddev', 'audSpec_Rfilt_sma_de[19]_quartile3', 'pcm_fftMag_spectralSlope_sma_amean', 'pcm_RMSenergy_sma_de_percentile1.0', 'pcm_fftMag_spectralEntropy_sma_maxSegLen', 'pcm_fftMag_spectralHarmonicity_sma_de_stddev', 'pcm_fftMag_spectralHarmonicity_sma_de_rqmean', 'audspec_lengthL1norm_sma_de_iqr1-2', 'logHNR_sma_qregc3', 'audspecRasta_lengthL1norm_sma_de_quartile3', 'pcm_RMSenergy_sma_lpgain', 'audspec_lengthL1norm_sma_de_quartile1', 'pcm_fftMag_spectralSlope_sma_de_percentile99.0', 'pcm_fftMag_spectralFlux_sma_stddev', 'mfcc_sma[10]_meanRisingSlope', 'pcm_fftMag_spectralHarmonicity_sma_amean', 'pcm_fftMag_spectralHarmonicity_sma_lpgain', 'audspec_lengthL1norm_sma_de_iqr1-3', 'pcm_fftMag_spectralRollOff90.0_sma_de_peakMeanRel', 'pcm_fftMag_spectralFlux_sma_iqr1-3', 'logHNR_sma_linregc2', 'pcm_fftMag_spectralHarmonicity_sma_de_quartile1', 'pcm_fftMag_spectralHarmonicity_sma_de_iqr1-2', 'mfcc_sma[13]_minPos', 'pcm_RMSenergy_sma_de_quartile3', 'pcm_RMSenergy_sma_de_iqr2-3', 'pcm_RMSenergy_sma_de_posamean', 'pcm_RMSenergy_sma_de_iqr1-2', 'pcm_fftMag_spectralFlux_sma_quartile3', 'pcm_fftMag_spectralSlope_sma_de_quartile3', 'pcm_fftMag_spectralSlope_sma_de_iqr2-3', 'pcm_RMSenergy_sma_de_quartile1', 'pcm_RMSenergy_sma_de_iqr1-3', 'pcm_fftMag_spectralSlope_sma_de_posamean', 'pcm_fftMag_spectralFlux_sma_de_iqr2-3', 'pcm_fftMag_spectralFlux_sma_de_quartile3', 'pcm_fftMag_spectralFlux_sma_de_stddev', 'pcm_fftMag_spectralFlux_sma_de_rqmean', 'pcm_fftMag_spectralRollOff25.0_sma_linregc2', 'pcm_fftMag_spectralFlux_sma_de_posamean', 'pcm_RMSenergy_sma_de_stddev', 'pcm_RMSenergy_sma_de_rqmean', 'pcm_fftMag_spectralFlux_sma_amean', 'pcm_fftMag_spectralFlux_sma_rqmean', 'pcm_fftMag_spectralFlux_sma_de_iqr1-2', 'pcm_fftMag_spectralFlux_sma_de_quartile1', 'pcm_fftMag_spectralFlux_sma_de_iqr1-3', 'mfcc_sma[14]_linregc2', 'pcm_fftMag_spectralFlux_sma_de_lpgain', 'pcm_fftMag_spectralFlux_sma_lpgain']

# %% [markdown]
# ### chi

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X_train)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_train.abs(), y_train)
# Out:
# SelectKBest(k=100, score_func=<function chi2 at 0x7f2a113dd710>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X_train.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=100, verbose=5)
rfe_selector.fit(X_train, y_train)
# Out:
# Fitting estimator with 6377 features.
# Fitting estimator with 6277 features.
# Fitting estimator with 6177 features.
# Fitting estimator with 6077 features.
# Fitting estimator with 5977 features.
# Fitting estimator with 5877 features.
# Fitting estimator with 5777 features.
# Fitting estimator with 5677 features.
# Fitting estimator with 5577 features.
# Fitting estimator with 5477 features.
# Fitting estimator with 5377 features.
# Fitting estimator with 5277 features.
# Fitting estimator with 5177 features.
# Fitting estimator with 5077 features.
# Fitting estimator with 4977 features.
# Fitting estimator with 4877 features.
# Fitting estimator with 4777 features.
# Fitting estimator with 4677 features.
# Fitting estimator with 4577 features.
# Fitting estimator with 4477 features.
# Fitting estimator with 4377 features.
# Fitting estimator with 4277 features.
# Fitting estimator with 4177 features.
# Fitting estimator with 4077 features.
# Fitting estimator with 3977 features.
# Fitting estimator with 3877 features.
# Fitting estimator with 3777 features.
# Fitting estimator with 3677 features.
# Fitting estimator with 3577 features.
# Fitting estimator with 3477 features.
# Fitting estimator with 3377 features.
# Fitting estimator with 3277 features.
# Fitting estimator with 3177 features.
# Fitting estimator with 3077 features.
# Fitting estimator with 2977 features.
# Fitting estimator with 2877 features.
# Fitting estimator with 2777 features.
# Fitting estimator with 2677 features.
# Fitting estimator with 2577 features.
# Fitting estimator with 2477 features.
# Fitting estimator with 2377 features.
# Fitting estimator with 2277 features.
# Fitting estimator with 2177 features.
# Fitting estimator with 2077 features.
# Fitting estimator with 1977 features.
# Fitting estimator with 1877 features.
# Fitting estimator with 1777 features.
# Fitting estimator with 1677 features.
# Fitting estimator with 1577 features.
# Fitting estimator with 1477 features.
# Fitting estimator with 1377 features.
# Fitting estimator with 1277 features.
# Fitting estimator with 1177 features.
# Fitting estimator with 1077 features.
# Fitting estimator with 977 features.
# Fitting estimator with 877 features.
# Fitting estimator with 777 features.
# Fitting estimator with 677 features.
# Fitting estimator with 577 features.
# Fitting estimator with 477 features.
# Fitting estimator with 377 features.
# Fitting estimator with 277 features.
# Fitting estimator with 177 features.
# RFE(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                  fit_intercept=True, intercept_scaling=1,
#                                  l1_ratio=None, max_iter=100,
#                                  multi_class='auto', n_jobs=None, penalty='l2',
#                                  random_state=None, solver='lbfgs', tol=0.0001,
#                                  verbose=0, warm_start=False),
#     n_features_to_select=100, step=100, verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X_train.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### SelectFromModel

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), '1.25*median')
embeded_lr_selector.fit(X_train, y_train)

embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X_train.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 2685 selected features

# %% [markdown]
# ### SelectFromRF

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='1.25*median')
embeded_rf_selector.fit(X_train, y_train)

embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X_train.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 2946 selected features

# %% [markdown]
# ### SelectFromlgbm

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier()
    # n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
    #         reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

embeded_lgb_selector = SelectFromModel(lgbc, threshold='1.75*median')
embeded_lgb_selector.fit(X_train, y_train)

embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X_train.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
# Out:
# 6377 selected features

# %%
X_train.shape
# Out:
# (810, 6377)

# %% [markdown]
# # Models correlation features

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



import warnings
warnings.filterwarnings('ignore')

# %%
features = X_train[cor_feature]
features2 = X_test[cor_feature]

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
X_test.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier()
# scores = cross_val_score(clf, features, y_train, cv=5)
# print(scores.mean())
clf.fit(features, y_train)
y_pred = (clf.predict(features2)>0.5).astype(int)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29        18
#            1       0.79      0.48      0.59        69
#
#     accuracy                           0.48        87
#    macro avg       0.49      0.49      0.44        87
# weighted avg       0.66      0.48      0.53        87

# %%
from sklearn.svm import SVC

svclassifier = SVC(gamma='auto')
svclassifier.fit(features, y_train)
y_pred = svclassifier.predict(features2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.24      0.34        45
#            1       0.49      0.79      0.61        42
#
#     accuracy                           0.51        87
#    macro avg       0.52      0.52      0.47        87
# weighted avg       0.52      0.51      0.47        87

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import product
from sklearn.ensemble import VotingClassifier


clf1 = DecisionTreeClassifier()
clf2 = KNeighborsClassifier()
clf3 = SVC(kernel='rbf', probability=True)
eclf = VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)],
                        voting='soft', weights=[2, 2, 2])

clf1 = clf1.fit(features, y_train)
clf2 = clf2.fit(features, y_train)
clf3 = clf3.fit(features, y_train)
eclf = eclf.fit(features, y_train)

for clf, label in zip([clf1, clf2, clf3, eclf], ['DecisionTreeClassifier', 'KNNClassifier', 'SVC', 'voting']):
    scores = cross_val_score(clf, features, y_train, scoring='accuracy', cv=5)
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.54 (+/- 0.02) [DecisionTreeClassifier]
# Accuracy: 0.56 (+/- 0.01) [KNNClassifier]
# Accuracy: 0.61 (+/- 0.01) [SVC]
# Accuracy: 0.55 (+/- 0.02) [voting]

# %%
# fitting logistic regression
lr = LogisticRegression()
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")

# fitting SVC
svc = svm.LinearSVC()
svc.fit(features, y_train)
predictionsSVC = svc.predict(features2)
scoreSVC = accuracy_score(y_test, predictionsSVC)
print(f"Support Vector Classifier score is {scoreSVC * 100}%\n")

# fitting decision tree classifier
clf = tree.DecisionTreeClassifier()
clf.fit(features, y_train)
predictionsTree = clf.predict(features2)
scoreTree = accuracy_score(y_test, predictionsTree)
print(f"Decision Tree Classifier score is {scoreTree * 100}%\n")

# fitting Random Forest classifier
clf1 = RandomForestClassifier(max_features=23)
clf1.fit(features, y_train)
predictionsTree1 = clf1.predict(features2)
scoreTree1 = accuracy_score(y_test, predictionsTree1)
print(f"Random Forest Classifier score is {scoreTree1 * 100}%\n")

# fitting XGBoost
# xgb = XGBClassifier()
# xgb.fit(features.to_numpy(), y_train)
# predictionsXGB = xgb.predict(X_test)
# predictionsXGB = (predictionsXGB>0.5).astype(int)
# scoreXGB = accuracy_score(y_test, predictionsXGB)
# print(f"XG Boost Classifier score is {scoreXGB * 100}%\n")

# fitting KNN Classifier
K = range(1, 20)
acc = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(features, y_train)
    predictionsKNN = knn.predict(features2)
    scoreKNN = accuracy_score(y_test, predictionsKNN)
    print(f"KNN Classifier score is {scoreKNN * 100}% with k = {k}")
    acc.append(scoreKNN*100)

# Elbow plot:
plt.plot(K, acc)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title("Elbow Curve without feature selection for Inter-Reseach Area")

plt.show()

# MLP / ANN
classifier = MLPClassifier(hidden_layer_sizes=(50, 15), max_iter=300, activation='relu', solver='adam', random_state=1)
classifier.fit(features, y_train)
predictionsMLP = classifier.predict(features2)
scoreMLP = accuracy_score(y_test, predictionsMLP)
print(f"\nMLP Classifier score is {scoreMLP * 100}%\n")
# Out:
# Logistic Regression score is 62.06896551724138%
#
# Support Vector Classifier score is 62.06896551724138%
#
# Decision Tree Classifier score is 51.724137931034484%
#
# Random Forest Classifier score is 54.02298850574713%
#
# KNN Classifier score is 65.51724137931035% with k = 1
# KNN Classifier score is 55.172413793103445% with k = 2
# KNN Classifier score is 58.620689655172406% with k = 3
# KNN Classifier score is 56.32183908045977% with k = 4
# KNN Classifier score is 56.32183908045977% with k = 5
# KNN Classifier score is 58.620689655172406% with k = 6
# KNN Classifier score is 59.77011494252874% with k = 7
# KNN Classifier score is 57.47126436781609% with k = 8
# KNN Classifier score is 56.32183908045977% with k = 9
# KNN Classifier score is 60.91954022988506% with k = 10
# KNN Classifier score is 55.172413793103445% with k = 11
# KNN Classifier score is 57.47126436781609% with k = 12
# KNN Classifier score is 57.47126436781609% with k = 13
# KNN Classifier score is 57.47126436781609% with k = 14
# KNN Classifier score is 55.172413793103445% with k = 15
# KNN Classifier score is 56.32183908045977% with k = 16
# KNN Classifier score is 55.172413793103445% with k = 17
# KNN Classifier score is 57.47126436781609% with k = 18
# KNN Classifier score is 56.32183908045977% with k = 19
# MLP Classifier score is 57.47126436781609%

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(features, y_train)
predictionsKNN = knn.predict(features2)
scoreKNN = accuracy_score(y_test, predictionsKNN)
print(f"KNN Classifier score is {scoreKNN * 100}")
print(classification_report(y_test, predictionsKNN))
# Out:
# KNN Classifier score is 58.620689655172406
#               precision    recall  f1-score   support
#
#            0       0.62      0.53      0.57        45
#            1       0.56      0.64      0.60        42
#
#     accuracy                           0.59        87
#    macro avg       0.59      0.59      0.59        87
# weighted avg       0.59      0.59      0.59        87

# %%
from sklearn.model_selection import GridSearchCV
leaf_size = list(range(1,10))
n_neighbors = list(range(1,30))
p=[1,2]
#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
#Create new KNN object
knn_2 = KNeighborsClassifier()
#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10)
#Fit the model
best_model = clf.fit(features,y_train)
#Print The value of best Hyperparameters
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
# Out:
# Best leaf_size: 1
# Best p: 2
# Best n_neighbors: 19

# %%
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(features, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.578601 using {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.569959 (0.040457) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.562963 (0.045818) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.570370 (0.040371) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.567901 (0.046849) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.567078 (0.047058) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.567901 (0.046849) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.570782 (0.042010) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.571193 (0.041919) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.570782 (0.042010) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.578189 (0.045089) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.577778 (0.045350) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.578601 (0.044483) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.578601 (0.048420) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.578601 (0.048420) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.576132 (0.048378) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
# fitting logistic regression
lr = LogisticRegression(C=0.1,penalty='l2',solver='liblinear')
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")
# Out:
# Logistic Regression score is 62.06896551724138%

# %%
print(classification_report(y_test, predictionsLR))

# %%
from sklearn.metrics import classification_report,confusion_matrix
# #Create a Gaussian Classifier
# clf=RandomForestClassifier()
# # RandomForestClassifier()
# #Train the model using the training sets y_pred=clf.predict(X_test)
# clf.fit(features,y_train)
# y_pred=clf.predict(features2)
# print(classification_report(y_test,y_pred))
import pandas as pd
feature_imp = pd.Series(lr.coef_[0], index=features.columns).sort_values(ascending=False)
feature_imp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp[:15], y=feature_imp.index[:15],orient='h')
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(features, y_train).predict(features2)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))

print(classification_report(y_test,y_pred))
# Out:
# Number of mislabeled points out of a total 87 points : 38
#               precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        45
#            1       0.56      0.43      0.49        42
#
#     accuracy                           0.56        87
#    macro avg       0.56      0.56      0.55        87
# weighted avg       0.56      0.56      0.56        87

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = GradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
# row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(features2)

print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.53      0.43        30
#            1       0.67      0.49      0.57        57
#
#     accuracy                           0.51        87
#    macro avg       0.51      0.51      0.50        87
# weighted avg       0.56      0.51      0.52        87

# %%
# histogram-based gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = HistGradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.71      0.49        24
#            1       0.83      0.56      0.67        63
#
#     accuracy                           0.60        87
#    macro avg       0.61      0.63      0.58        87
# weighted avg       0.71      0.60      0.62        87

# %%
# xgboost for classification
from numpy import asarray
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = XGBClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = XGBClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-d09c43bec544> in <module>()
#      17 # fit the model on the whole dataset
#      18 model = XGBClassifier()
# ---> 19 model.fit(features, y_train)
#      20 # make a single prediction
#      21 yhat = model.predict(features2)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     424                 self.set_weight(weight)
#     425
# --> 426         self.feature_names = feature_names
#     427         self.feature_types = feature_types
#     428
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in feature_names(self, feature_names)
#     868                        not any(x in f for x in set(('[', ']', '<')))
#     869                        for f in feature_names):
# --> 870                 raise ValueError('feature_names may not contain [, ] or <')
#     871         else:
#     872             # reset feature_types also
#
# ValueError: feature_names may not contain [, ] or <

# %%
# lightgbm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = LGBMClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = LGBMClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.64      0.49        28
#            1       0.76      0.54      0.63        59
#
#     accuracy                           0.57        87
#    macro avg       0.58      0.59      0.56        87
# weighted avg       0.65      0.57      0.59        87

# %%
kernels = ['Polynomial', 'RBF', 'Sigmoid','Linear']#A function which returns the corresponding SVC model
def getClassifier(ktype):
    if ktype == 0:
        # Polynomial kernal
        return SVC(kernel='poly', degree=8, gamma="auto")
    elif ktype == 1:
        # Radial Basis Function kernal
        return SVC(kernel='rbf', gamma="auto")
    elif ktype == 2:
        # Sigmoid kernal
        return SVC(kernel='sigmoid', gamma="auto")
    elif ktype == 3:
        # Linear kernal
        return SVC(kernel='linear', gamma="auto")

for i in range(4):
    # Separate data into test and training sets
    # X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)# Train a SVC model using different kernal
    svclassifier = getClassifier(i) 
    svclassifier.fit(features, y_train)# Make prediction
    y_pred = svclassifier.predict(features2)# Evaluate our model
    print("Evaluation:", kernels[i], "kernel")
    print(classification_report(y_test,y_pred))
# Out:
# Evaluation: Polynomial kernel
#               precision    recall  f1-score   support
#
#            0       0.54      0.89      0.67        45
#            1       0.62      0.19      0.29        42
#
#     accuracy                           0.55        87
#    macro avg       0.58      0.54      0.48        87
# weighted avg       0.58      0.55      0.49        87
#
# Evaluation: RBF kernel
#               precision    recall  f1-score   support
#
#            0       0.70      0.31      0.43        45
#            1       0.54      0.86      0.66        42
#
#     accuracy                           0.57        87
#    macro avg       0.62      0.58      0.55        87
# weighted avg       0.62      0.57      0.54        87
#
# Evaluation: Sigmoid kernel
#               precision    recall  f1-score   support
#
#            0       0.50      0.24      0.33        45
#            1       0.48      0.74      0.58        42
#
#     accuracy                           0.48        87
#    macro avg       0.49      0.49      0.45        87
# weighted avg       0.49      0.48      0.45        87
#
# Evaluation: Linear kernel
#               precision    recall  f1-score   support
#
#            0       0.67      0.53      0.59        45
#            1       0.59      0.71      0.65        42
#
#     accuracy                           0.62        87
#    macro avg       0.63      0.62      0.62        87
# weighted avg       0.63      0.62      0.62        87

# %%
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(features, y_train)
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.623, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.654, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.574, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.623, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.654, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.574, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.623, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.654, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.574, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.623, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.654, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.574, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=linear ...............................
# [CV] ... C=0.1, gamma=0.001, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.623, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.654, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.605, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.574, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=0.1, gamma=0.0001, kernel=linear, score=0.605, total=   0.1s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.574, total=   0.2s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.611, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.574, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.611, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.574, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.611, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.574, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.611, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.574, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.586, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.562, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=linear ................................
# [CV] .... C=1, gamma=0.0001, kernel=linear, score=0.611, total=   0.2s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.593, total=   2.0s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.568, total=   1.7s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.617, total=   1.1s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.574, total=   1.7s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.593, total=   2.1s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.593, total=   2.0s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.568, total=   1.7s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.617, total=   1.1s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.574, total=   1.8s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.593, total=   2.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.593, total=   2.0s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.568, total=   1.7s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.617, total=   1.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.574, total=   1.7s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.593, total=   2.1s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.593, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.568, total=   1.7s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.617, total=   1.1s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.574, total=   1.7s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.593, total=   2.1s
# [CV] C=10, gamma=0.0001, kernel=linear ...............................
# [CV] ... C=10, gamma=0.0001, kernel=linear, score=0.593, total=   2.0s
# [CV] C=10, gamma=0.0001, kernel=linear ...............................
# [CV] ... C=10, gamma=0.0001, kernel=linear, score=0.568, total=   1.7s
# [CV] C=10, gamma=0.0001, kernel=linear ...............................
# [CV] ... C=10, gamma=0.0001, kernel=linear, score=0.617, total=   1.1s
# [CV] C=10, gamma=0.0001, kernel=linear ...............................
# [CV] ... C=10, gamma=0.0001, kernel=linear, score=0.574, total=   1.7s
# [CV] C=10, gamma=0.0001, kernel=linear ...............................
# [CV] ... C=10, gamma=0.0001, kernel=linear, score=0.593, total=   2.1s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.586, total=  14.9s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.537, total=  11.5s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.605, total=  16.1s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.556, total=  31.9s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.611, total=  22.2s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.586, total=  14.8s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.537, total=  11.5s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.605, total=  16.0s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.556, total=  31.8s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.611, total=  22.1s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.586, total=  14.8s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.537, total=  11.5s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.605, total=  16.0s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.556, total=  31.9s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.611, total=  22.1s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.586, total=  14.8s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.537, total=  11.5s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.605, total=  16.1s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.556, total=  31.9s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.611, total=  22.1s
# [CV] C=100, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=100, gamma=0.0001, kernel=linear, score=0.586, total=  14.8s
# [CV] C=100, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=100, gamma=0.0001, kernel=linear, score=0.537, total=  11.5s
# [CV] C=100, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=100, gamma=0.0001, kernel=linear, score=0.605, total=  16.1s
# [CV] C=100, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=100, gamma=0.0001, kernel=linear, score=0.556, total=  31.8s
# [CV] C=100, gamma=0.0001, kernel=linear ..............................
# [CV] .. C=100, gamma=0.0001, kernel=linear, score=0.611, total=  22.1s
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ...... C=1000, gamma=1, kernel=linear, score=0.568, total= 4.3min
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ...... C=1000, gamma=1, kernel=linear, score=0.506, total= 2.4min
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ...... C=1000, gamma=1, kernel=linear, score=0.605, total= 3.5min
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ...... C=1000, gamma=1, kernel=linear, score=0.556, total= 4.4min
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ...... C=1000, gamma=1, kernel=linear, score=0.593, total= 3.2min
# [CV] C=1000, gamma=0.1, kernel=linear ................................
# [CV] .... C=1000, gamma=0.1, kernel=linear, score=0.568, total= 4.3min
# [CV] C=1000, gamma=0.1, kernel=linear ................................
# [CV] .... C=1000, gamma=0.1, kernel=linear, score=0.506, total= 2.4min
# [CV] C=1000, gamma=0.1, kernel=linear ................................
# [CV] .... C=1000, gamma=0.1, kernel=linear, score=0.605, total= 3.5min
# [CV] C=1000, gamma=0.1, kernel=linear ................................
# [CV] .... C=1000, gamma=0.1, kernel=linear, score=0.556, total= 4.4min
# [CV] C=1000, gamma=0.1, kernel=linear ................................
# [CV] .... C=1000, gamma=0.1, kernel=linear, score=0.593, total= 3.3min
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ... C=1000, gamma=0.01, kernel=linear, score=0.568, total= 4.3min
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ... C=1000, gamma=0.01, kernel=linear, score=0.506, total= 2.4min
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ... C=1000, gamma=0.01, kernel=linear, score=0.605, total= 3.5min
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ... C=1000, gamma=0.01, kernel=linear, score=0.556, total= 4.4min
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ... C=1000, gamma=0.01, kernel=linear, score=0.593, total= 3.3min
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] .. C=1000, gamma=0.001, kernel=linear, score=0.568, total= 4.3min
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] .. C=1000, gamma=0.001, kernel=linear, score=0.506, total= 2.4min
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] .. C=1000, gamma=0.001, kernel=linear, score=0.605, total= 3.5min
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] .. C=1000, gamma=0.001, kernel=linear, score=0.556, total= 4.4min
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] .. C=1000, gamma=0.001, kernel=linear, score=0.593, total= 3.3min
# [CV] C=1000, gamma=0.0001, kernel=linear .............................
# [CV] . C=1000, gamma=0.0001, kernel=linear, score=0.568, total= 4.3min
# [CV] C=1000, gamma=0.0001, kernel=linear .............................
# [CV] . C=1000, gamma=0.0001, kernel=linear, score=0.506, total= 2.4min
# [CV] C=1000, gamma=0.0001, kernel=linear .............................
# [CV] . C=1000, gamma=0.0001, kernel=linear, score=0.605, total= 3.5min
# [CV] C=1000, gamma=0.0001, kernel=linear .............................
# [CV] . C=1000, gamma=0.0001, kernel=linear, score=0.556, total= 4.4min
# [CV] C=1000, gamma=0.0001, kernel=linear .............................
# [CV] . C=1000, gamma=0.0001, kernel=linear, score=0.593, total= 3.3min
# {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# SVC(C=0.1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed: 98.5min finished

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/b9/f4/c5b95cddae15be80f8e58b25edceca105aa83c0b8c86a1edad24a6af80d3/shap-0.39.0.tar.gz (356kB)
#      |████████████████████████████████| 358kB 8.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.41.1)
# Collecting slicer==0.0.7
#   Downloading https://files.pythonhosted.org/packages/78/c2/b3f55dfdb8af9812fdb9baf70cacf3b9e82e505b2bd4324d588888b81202/slicer-0.0.7-py3-none-any.whl
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.39.0-cp37-cp37m-linux_x86_64.whl size=491619 sha256=9294f71dc1544731d23bec9df0c901cf8da8459b85fc63ac4f6dfe9700b12b1b
#   Stored in directory: /root/.cache/pip/wheels/15/27/f5/a8ab9da52fd159aae6477b5ede6eaaec69fd130fa0fa59f283
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.39.0 slicer-0.0.7

# %%
import shap
explainer = shap.Explainer(svclassifier)
shap_values = explainer(features)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-89-bbebfc93c447> in <module>()
#       1 import shap
# ----> 2 explainer = shap.Explainer(svclassifier)
#       3 shap_values = explainer(features)
#       4
#       5 # visualize the first prediction's explanation
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/_explainer.py in __init__(self, model, masker, link, algorithm, output_names, feature_names, **kwargs)
#     166                 # if we get here then we don't know how to handle what was given to us
#     167                 else:
# --> 168                     raise Exception("The passed model is not callable and cannot be analyzed directly with the given masker! Model: " + str(model))
#     169
#     170             # build the right subclass
#
# Exception: The passed model is not callable and cannot be analyzed directly with the given masker! Model: SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
from sklearn.metrics import classification_report,confusion_matrix
# #Create a Gaussian Classifier
# clf=RandomForestClassifier()
# # RandomForestClassifier()
# #Train the model using the training sets y_pred=clf.predict(X_test)
# clf.fit(features,y_train)
# y_pred=clf.predict(features2)
# print(classification_report(y_test,y_pred))
import pandas as pd
feature_imp = pd.Series(svclassifier.coef_[0], index=features.columns).sort_values(ascending=False)
feature_imp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp[:15], y=feature_imp.index[:15],orient='h')
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Models chi

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



import warnings
warnings.filterwarnings('ignore')

# %%
features = X_train[chi_feature]
features2 = X_test[chi_feature]

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
X_test.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier()
# scores = cross_val_score(clf, features, y_train, cv=5)
# print(scores.mean())
clf.fit(features, y_train)
y_pred = (clf.predict(features2)>0.5).astype(int)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.54      0.39        26
#            1       0.71      0.49      0.58        61
#
#     accuracy                           0.51        87
#    macro avg       0.51      0.52      0.49        87
# weighted avg       0.59      0.51      0.53        87

# %%
from sklearn.svm import SVC

svclassifier = SVC(gamma='auto')
svclassifier.fit(features, y_train)
y_pred = svclassifier.predict(features2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.04      0.08        45
#            1       0.49      0.98      0.65        42
#
#     accuracy                           0.49        87
#    macro avg       0.58      0.51      0.37        87
# weighted avg       0.58      0.49      0.36        87

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import product
from sklearn.ensemble import VotingClassifier


clf1 = DecisionTreeClassifier()
clf2 = KNeighborsClassifier()
clf3 = SVC(kernel='rbf', probability=True)
eclf = VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)],
                        voting='soft', weights=[2, 2, 2])

clf1 = clf1.fit(features, y_train)
clf2 = clf2.fit(features, y_train)
clf3 = clf3.fit(features, y_train)
eclf = eclf.fit(features, y_train)

for clf, label in zip([clf1, clf2, clf3, eclf], ['DecisionTreeClassifier', 'KNNClassifier', 'SVC', 'voting']):
    scores = cross_val_score(clf, features, y_train, scoring='accuracy', cv=5)
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.52 (+/- 0.05) [DecisionTreeClassifier]
# Accuracy: 0.55 (+/- 0.01) [KNNClassifier]
# Accuracy: 0.52 (+/- 0.00) [SVC]
# Accuracy: 0.51 (+/- 0.04) [voting]

# %%
# fitting logistic regression
lr = LogisticRegression()
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")

# fitting SVC
svc = svm.LinearSVC()
svc.fit(features, y_train)
predictionsSVC = svc.predict(features2)
scoreSVC = accuracy_score(y_test, predictionsSVC)
print(f"Support Vector Classifier score is {scoreSVC * 100}%\n")

# fitting decision tree classifier
clf = tree.DecisionTreeClassifier()
clf.fit(features, y_train)
predictionsTree = clf.predict(features2)
scoreTree = accuracy_score(y_test, predictionsTree)
print(f"Decision Tree Classifier score is {scoreTree * 100}%\n")

# fitting Random Forest classifier
clf1 = RandomForestClassifier(max_features=23)
clf1.fit(features, y_train)
predictionsTree1 = clf1.predict(features2)
scoreTree1 = accuracy_score(y_test, predictionsTree1)
print(f"Random Forest Classifier score is {scoreTree1 * 100}%\n")

# fitting XGBoost
# xgb = XGBClassifier()
# xgb.fit(features.to_numpy(), y_train)
# predictionsXGB = xgb.predict(X_test)
# predictionsXGB = (predictionsXGB>0.5).astype(int)
# scoreXGB = accuracy_score(y_test, predictionsXGB)
# print(f"XG Boost Classifier score is {scoreXGB * 100}%\n")

# fitting KNN Classifier
K = range(1, 20)
acc = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(features, y_train)
    predictionsKNN = knn.predict(features2)
    scoreKNN = accuracy_score(y_test, predictionsKNN)
    print(f"KNN Classifier score is {scoreKNN * 100}% with k = {k}")
    acc.append(scoreKNN*100)

# Elbow plot:
plt.plot(K, acc)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title("Elbow Curve without feature selection for Inter-Reseach Area")

plt.show()

# MLP / ANN
classifier = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300, activation='relu', solver='adam', random_state=1)
classifier.fit(features, y_train)
predictionsMLP = classifier.predict(features2)
scoreMLP = accuracy_score(y_test, predictionsMLP)
print(f"\nMLP Classifier score is {scoreMLP * 100}%\n")
# Out:
# Logistic Regression score is 50.57471264367817%
#
# Support Vector Classifier score is 51.724137931034484%
#
# Decision Tree Classifier score is 51.724137931034484%
#
# Random Forest Classifier score is 52.87356321839081%
#
# KNN Classifier score is 48.275862068965516% with k = 1
# KNN Classifier score is 54.02298850574713% with k = 2
# KNN Classifier score is 50.57471264367817% with k = 3
# KNN Classifier score is 51.724137931034484% with k = 4
# KNN Classifier score is 50.57471264367817% with k = 5
# KNN Classifier score is 51.724137931034484% with k = 6
# KNN Classifier score is 48.275862068965516% with k = 7
# KNN Classifier score is 51.724137931034484% with k = 8
# KNN Classifier score is 48.275862068965516% with k = 9
# KNN Classifier score is 49.42528735632184% with k = 10
# KNN Classifier score is 48.275862068965516% with k = 11
# KNN Classifier score is 50.57471264367817% with k = 12
# KNN Classifier score is 48.275862068965516% with k = 13
# KNN Classifier score is 54.02298850574713% with k = 14
# KNN Classifier score is 52.87356321839081% with k = 15
# KNN Classifier score is 54.02298850574713% with k = 16
# KNN Classifier score is 56.32183908045977% with k = 17
# KNN Classifier score is 52.87356321839081% with k = 18
# KNN Classifier score is 54.02298850574713% with k = 19
# MLP Classifier score is 51.724137931034484%

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(features, y_train).predict(features2)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 87 points : 46

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = GradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
# row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(features2)

print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.53      0.43        30
#            1       0.67      0.49      0.57        57
#
#     accuracy                           0.51        87
#    macro avg       0.51      0.51      0.50        87
# weighted avg       0.56      0.51      0.52        87

# %%
# histogram-based gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = HistGradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.50      0.43        34
#            1       0.60      0.47      0.53        53
#
#     accuracy                           0.48        87
#    macro avg       0.49      0.49      0.48        87
# weighted avg       0.51      0.48      0.49        87

# %%
# xgboost for classification
from numpy import asarray
from numpy import mean
from numpy import std
# from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = XGBClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = XGBClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-6eac32dd02d6> in <module>()
#      17 # fit the model on the whole dataset
#      18 model = XGBClassifier()
# ---> 19 model.fit(features, y_train)
#      20 # make a single prediction
#      21 yhat = model.predict(features2)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     424                 self.set_weight(weight)
#     425
# --> 426         self.feature_names = feature_names
#     427         self.feature_types = feature_types
#     428
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in feature_names(self, feature_names)
#     868                        not any(x in f for x in set(('[', ']', '<')))
#     869                        for f in feature_names):
# --> 870                 raise ValueError('feature_names may not contain [, ] or <')
#     871         else:
#     872             # reset feature_types also
#
# ValueError: feature_names may not contain [, ] or <

# %%
# lightgbm for classification
from numpy import mean
from numpy import std
# from sklearn.datasets import make_classification
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = LGBMClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = LGBMClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40        30
#            1       0.64      0.47      0.55        57
#
#     accuracy                           0.48        87
#    macro avg       0.49      0.49      0.47        87
# weighted avg       0.54      0.48      0.50        87

# %% [markdown]
# # Models rfe features

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



import warnings
warnings.filterwarnings('ignore')

# %%
features = X_train[rfe_feature]
features2 = X_test[rfe_feature]

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
X_test.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier()
# scores = cross_val_score(clf, features, y_train, cv=5)
# print(scores.mean())
clf.fit(features, y_train)
y_pred = (clf.predict(features2)>0.5).astype(int)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.68      0.52        28
#            1       0.79      0.56      0.65        59
#
#     accuracy                           0.60        87
#    macro avg       0.60      0.62      0.59        87
# weighted avg       0.67      0.60      0.61        87

# %%
from sklearn.svm import SVC

svclassifier = SVC(gamma='auto')
svclassifier.fit(features, y_train)
y_pred = svclassifier.predict(features2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.24      0.34        45
#            1       0.49      0.79      0.61        42
#
#     accuracy                           0.51        87
#    macro avg       0.52      0.52      0.47        87
# weighted avg       0.52      0.51      0.47        87

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import product
from sklearn.ensemble import VotingClassifier


clf1 = DecisionTreeClassifier()
clf2 = KNeighborsClassifier()
clf3 = SVC(kernel='rbf', probability=True)
eclf = VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)],
                        voting='soft', weights=[2, 2, 2])

clf1 = clf1.fit(features, y_train)
clf2 = clf2.fit(features, y_train)
clf3 = clf3.fit(features, y_train)
eclf = eclf.fit(features, y_train)

for clf, label in zip([clf1, clf2, clf3, eclf], ['DecisionTreeClassifier', 'KNNClassifier', 'SVC', 'voting']):
    scores = cross_val_score(clf, features, y_train, scoring='accuracy', cv=5)
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.56 (+/- 0.03) [DecisionTreeClassifier]
# Accuracy: 0.58 (+/- 0.03) [KNNClassifier]
# Accuracy: 0.70 (+/- 0.04) [SVC]
# Accuracy: 0.58 (+/- 0.04) [voting]

# %%
# fitting logistic regression
lr = LogisticRegression()
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")

# fitting SVC
svc = svm.LinearSVC()
svc.fit(features, y_train)
predictionsSVC = svc.predict(features2)
scoreSVC = accuracy_score(y_test, predictionsSVC)
print(f"Support Vector Classifier score is {scoreSVC * 100}%\n")

# fitting decision tree classifier
clf = tree.DecisionTreeClassifier()
clf.fit(features, y_train)
predictionsTree = clf.predict(features2)
scoreTree = accuracy_score(y_test, predictionsTree)
print(f"Decision Tree Classifier score is {scoreTree * 100}%\n")

# fitting Random Forest classifier
clf1 = RandomForestClassifier(max_features=23)
clf1.fit(features, y_train)
predictionsTree1 = clf1.predict(features2)
scoreTree1 = accuracy_score(y_test, predictionsTree1)
print(f"Random Forest Classifier score is {scoreTree1 * 100}%\n")

# fitting XGBoost
# xgb = XGBClassifier()
# xgb.fit(features.to_numpy(), y_train)
# predictionsXGB = xgb.predict(X_test)
# predictionsXGB = (predictionsXGB>0.5).astype(int)
# scoreXGB = accuracy_score(y_test, predictionsXGB)
# print(f"XG Boost Classifier score is {scoreXGB * 100}%\n")

# fitting KNN Classifier
K = range(1, 20)
acc = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(features, y_train)
    predictionsKNN = knn.predict(features2)
    scoreKNN = accuracy_score(y_test, predictionsKNN)
    print(f"KNN Classifier score is {scoreKNN * 100}% with k = {k}")
    acc.append(scoreKNN*100)

# Elbow plot:
plt.plot(K, acc)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title("Elbow Curve without feature selection for Inter-Reseach Area")

plt.show()

# MLP / ANN
classifier = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300, activation='relu', solver='adam', random_state=1)
classifier.fit(features, y_train)
predictionsMLP = classifier.predict(features2)
scoreMLP = accuracy_score(y_test, predictionsMLP)
print(f"\nMLP Classifier score is {scoreMLP * 100}%\n")
# Out:
# Logistic Regression score is 51.724137931034484%
#
# Support Vector Classifier score is 52.87356321839081%
#
# Decision Tree Classifier score is 45.97701149425287%
#
# Random Forest Classifier score is 49.42528735632184%
#
# KNN Classifier score is 44.827586206896555% with k = 1
# KNN Classifier score is 54.02298850574713% with k = 2
# KNN Classifier score is 44.827586206896555% with k = 3
# KNN Classifier score is 45.97701149425287% with k = 4
# KNN Classifier score is 51.724137931034484% with k = 5
# KNN Classifier score is 49.42528735632184% with k = 6
# KNN Classifier score is 49.42528735632184% with k = 7
# KNN Classifier score is 50.57471264367817% with k = 8
# KNN Classifier score is 52.87356321839081% with k = 9
# KNN Classifier score is 56.32183908045977% with k = 10
# KNN Classifier score is 54.02298850574713% with k = 11
# KNN Classifier score is 55.172413793103445% with k = 12
# KNN Classifier score is 58.620689655172406% with k = 13
# KNN Classifier score is 57.47126436781609% with k = 14
# KNN Classifier score is 55.172413793103445% with k = 15
# KNN Classifier score is 59.77011494252874% with k = 16
# KNN Classifier score is 58.620689655172406% with k = 17
# KNN Classifier score is 58.620689655172406% with k = 18
# KNN Classifier score is 55.172413793103445% with k = 19
# MLP Classifier score is 52.87356321839081%

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(features, y_train).predict(features2)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 87 points : 41

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = GradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
# row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(features2)

print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.58      0.41        24
#            1       0.76      0.51      0.61        63
#
#     accuracy                           0.53        87
#    macro avg       0.54      0.55      0.51        87
# weighted avg       0.64      0.53      0.55        87

# %%
# histogram-based gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = HistGradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.16      0.47      0.23        15
#            1       0.81      0.47      0.60        72
#
#     accuracy                           0.47        87
#    macro avg       0.48      0.47      0.41        87
# weighted avg       0.70      0.47      0.53        87

# %%
# xgboost for classification
from numpy import asarray
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = XGBClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = XGBClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-3e5eb772ea61> in <module>()
#      17 # fit the model on the whole dataset
#      18 model = XGBClassifier()
# ---> 19 model.fit(features, y_train)
#      20 # make a single prediction
#      21 yhat = model.predict(features2)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     424                 self.set_weight(weight)
#     425
# --> 426         self.feature_names = feature_names
#     427         self.feature_types = feature_types
#     428
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in feature_names(self, feature_names)
#     868                        not any(x in f for x in set(('[', ']', '<')))
#     869                        for f in feature_names):
# --> 870                 raise ValueError('feature_names may not contain [, ] or <')
#     871         else:
#     872             # reset feature_types also
#
# ValueError: feature_names may not contain [, ] or <

# %%
# lightgbm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = LGBMClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = LGBMClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.61      0.35        18
#            1       0.83      0.51      0.63        69
#
#     accuracy                           0.53        87
#    macro avg       0.54      0.56      0.49        87
# weighted avg       0.71      0.53      0.57        87

# %% [markdown]
# # Models embed

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



import warnings
warnings.filterwarnings('ignore')

# %%
features = X_train[embeded_lr_feature]
features2 = X_test[embeded_lr_feature]

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
X_test.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier()
# scores = cross_val_score(clf, features, y_train, cv=5)
# print(scores.mean())
clf.fit(features, y_train)
y_pred = (clf.predict(features2)>0.5).astype(int)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.52      0.39        27
#            1       0.69      0.48      0.57        60
#
#     accuracy                           0.49        87
#    macro avg       0.50      0.50      0.48        87
# weighted avg       0.57      0.49      0.51        87

# %%
from sklearn.svm import SVC

svclassifier = SVC(gamma='auto')
svclassifier.fit(features, y_train)
y_pred = svclassifier.predict(features2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.20      0.29        45
#            1       0.49      0.81      0.61        42
#
#     accuracy                           0.49        87
#    macro avg       0.51      0.50      0.45        87
# weighted avg       0.51      0.49      0.44        87

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import product
from sklearn.ensemble import VotingClassifier


clf1 = DecisionTreeClassifier()
clf2 = KNeighborsClassifier()
clf3 = SVC(kernel='rbf', probability=True)
eclf = VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)],
                        voting='soft', weights=[2, 2, 2])

clf1 = clf1.fit(features, y_train)
clf2 = clf2.fit(features, y_train)
clf3 = clf3.fit(features, y_train)
eclf = eclf.fit(features, y_train)

for clf, label in zip([clf1, clf2, clf3, eclf], ['DecisionTreeClassifier', 'KNNClassifier', 'SVC', 'voting']):
    scores = cross_val_score(clf, features, y_train, scoring='accuracy', cv=5)
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.51 (+/- 0.04) [DecisionTreeClassifier]
# Accuracy: 0.54 (+/- 0.01) [KNNClassifier]
# Accuracy: 0.59 (+/- 0.02) [SVC]
# Accuracy: 0.53 (+/- 0.04) [voting]

# %%
# fitting logistic regression
lr = LogisticRegression()
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")

# fitting SVC
svc = svm.LinearSVC()
svc.fit(features, y_train)
predictionsSVC = svc.predict(features2)
scoreSVC = accuracy_score(y_test, predictionsSVC)
print(f"Support Vector Classifier score is {scoreSVC * 100}%\n")

# fitting decision tree classifier
clf = tree.DecisionTreeClassifier()
clf.fit(features, y_train)
predictionsTree = clf.predict(features2)
scoreTree = accuracy_score(y_test, predictionsTree)
print(f"Decision Tree Classifier score is {scoreTree * 100}%\n")

# fitting Random Forest classifier
clf1 = RandomForestClassifier(max_features=23)
clf1.fit(features, y_train)
predictionsTree1 = clf1.predict(features2)
scoreTree1 = accuracy_score(y_test, predictionsTree1)
print(f"Random Forest Classifier score is {scoreTree1 * 100}%\n")

# fitting XGBoost
# xgb = XGBClassifier()
# xgb.fit(features.to_numpy(), y_train)
# predictionsXGB = xgb.predict(X_test)
# predictionsXGB = (predictionsXGB>0.5).astype(int)
# scoreXGB = accuracy_score(y_test, predictionsXGB)
# print(f"XG Boost Classifier score is {scoreXGB * 100}%\n")

# fitting KNN Classifier
K = range(1, 20)
acc = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(features, y_train)
    predictionsKNN = knn.predict(features2)
    scoreKNN = accuracy_score(y_test, predictionsKNN)
    print(f"KNN Classifier score is {scoreKNN * 100}% with k = {k}")
    acc.append(scoreKNN*100)

# Elbow plot:
plt.plot(K, acc)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title("Elbow Curve without feature selection for Inter-Reseach Area")

plt.show()

# MLP / ANN
classifier = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300, activation='relu', solver='adam', random_state=1)
classifier.fit(features, y_train)
predictionsMLP = classifier.predict(features2)
scoreMLP = accuracy_score(y_test, predictionsMLP)
print(f"\nMLP Classifier score is {scoreMLP * 100}%\n")
# Out:
# Logistic Regression score is 56.32183908045977%
#
# Support Vector Classifier score is 55.172413793103445%
#
# Decision Tree Classifier score is 47.12643678160919%
#
# Random Forest Classifier score is 48.275862068965516%
#
# KNN Classifier score is 48.275862068965516% with k = 1
# KNN Classifier score is 49.42528735632184% with k = 2
# KNN Classifier score is 44.827586206896555% with k = 3
# KNN Classifier score is 42.5287356321839% with k = 4
# KNN Classifier score is 45.97701149425287% with k = 5
# KNN Classifier score is 42.5287356321839% with k = 6
# KNN Classifier score is 51.724137931034484% with k = 7
# KNN Classifier score is 49.42528735632184% with k = 8
# KNN Classifier score is 49.42528735632184% with k = 9
# KNN Classifier score is 51.724137931034484% with k = 10
# KNN Classifier score is 50.57471264367817% with k = 11
# KNN Classifier score is 44.827586206896555% with k = 12
# KNN Classifier score is 45.97701149425287% with k = 13
# KNN Classifier score is 48.275862068965516% with k = 14
# KNN Classifier score is 49.42528735632184% with k = 15
# KNN Classifier score is 51.724137931034484% with k = 16
# KNN Classifier score is 51.724137931034484% with k = 17
# KNN Classifier score is 51.724137931034484% with k = 18
# KNN Classifier score is 50.57471264367817% with k = 19
# MLP Classifier score is 50.57471264367817%

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(features, y_train).predict(features2)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 87 points : 44

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = GradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
# row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(features2)

print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.52      0.37        25
#            1       0.71      0.48      0.58        62
#
#     accuracy                           0.49        87
#    macro avg       0.50      0.50      0.47        87
# weighted avg       0.59      0.49      0.52        87

# %%
# histogram-based gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = HistGradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.60      0.37        20
#            1       0.81      0.51      0.62        67
#
#     accuracy                           0.53        87
#    macro avg       0.54      0.55      0.50        87
# weighted avg       0.68      0.53      0.57        87

# %%
# xgboost for classification
from numpy import asarray
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = XGBClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = XGBClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-3e5eb772ea61> in <module>()
#      17 # fit the model on the whole dataset
#      18 model = XGBClassifier()
# ---> 19 model.fit(features, y_train)
#      20 # make a single prediction
#      21 yhat = model.predict(features2)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     424                 self.set_weight(weight)
#     425
# --> 426         self.feature_names = feature_names
#     427         self.feature_types = feature_types
#     428
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in feature_names(self, feature_names)
#     868                        not any(x in f for x in set(('[', ']', '<')))
#     869                        for f in feature_names):
# --> 870                 raise ValueError('feature_names may not contain [, ] or <')
#     871         else:
#     872             # reset feature_types also
#
# ValueError: feature_names may not contain [, ] or <

# %%
# lightgbm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = LGBMClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = LGBMClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.65      0.35        17
#            1       0.86      0.51      0.64        70
#
#     accuracy                           0.54        87
#    macro avg       0.55      0.58      0.50        87
# weighted avg       0.74      0.54      0.59        87

# %% [markdown]
# # Models embed rf

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
features = X_train[embeded_rf_feature]
features2 = X_test[embeded_rf_feature]

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
X_test.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier()
# scores = cross_val_score(clf, features, y_train, cv=5)
# print(scores.mean())
clf.fit(features, y_train)
y_pred = (clf.predict(features2)>0.5).astype(int)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.42      0.29        24
#            1       0.67      0.44      0.53        63
#
#     accuracy                           0.44        87
#    macro avg       0.44      0.43      0.41        87
# weighted avg       0.54      0.44      0.47        87

# %%
from sklearn.svm import SVC

svclassifier = SVC(gamma='auto')
svclassifier.fit(features, y_train)
y_pred = svclassifier.predict(features2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.20      0.28        45
#            1       0.47      0.76      0.58        42
#
#     accuracy                           0.47        87
#    macro avg       0.47      0.48      0.43        87
# weighted avg       0.47      0.47      0.43        87

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import product
from sklearn.ensemble import VotingClassifier


clf1 = DecisionTreeClassifier()
clf2 = KNeighborsClassifier()
clf3 = SVC(kernel='rbf', probability=True)
eclf = VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)],
                        voting='soft', weights=[2, 2, 2])

clf1 = clf1.fit(features, y_train)
clf2 = clf2.fit(features, y_train)
clf3 = clf3.fit(features, y_train)
eclf = eclf.fit(features, y_train)

for clf, label in zip([clf1, clf2, clf3, eclf], ['DecisionTreeClassifier', 'KNNClassifier', 'SVC', 'voting']):
    scores = cross_val_score(clf, features, y_train, scoring='accuracy', cv=5)
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.51 (+/- 0.01) [DecisionTreeClassifier]
# Accuracy: 0.52 (+/- 0.03) [KNNClassifier]
# Accuracy: 0.55 (+/- 0.02) [SVC]
# Accuracy: 0.53 (+/- 0.04) [voting]

# %%
# fitting logistic regression
lr = LogisticRegression()
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")

# fitting SVC
svc = svm.LinearSVC()
svc.fit(features, y_train)
predictionsSVC = svc.predict(features2)
scoreSVC = accuracy_score(y_test, predictionsSVC)
print(f"Support Vector Classifier score is {scoreSVC * 100}%\n")

# fitting decision tree classifier
clf = tree.DecisionTreeClassifier()
clf.fit(features, y_train)
predictionsTree = clf.predict(features2)
scoreTree = accuracy_score(y_test, predictionsTree)
print(f"Decision Tree Classifier score is {scoreTree * 100}%\n")

# fitting Random Forest classifier
clf1 = RandomForestClassifier(max_features=23)
clf1.fit(features, y_train)
predictionsTree1 = clf1.predict(features2)
scoreTree1 = accuracy_score(y_test, predictionsTree1)
print(f"Random Forest Classifier score is {scoreTree1 * 100}%\n")

# fitting XGBoost
# xgb = XGBClassifier()
# xgb.fit(features.to_numpy(), y_train)
# predictionsXGB = xgb.predict(X_test)
# predictionsXGB = (predictionsXGB>0.5).astype(int)
# scoreXGB = accuracy_score(y_test, predictionsXGB)
# print(f"XG Boost Classifier score is {scoreXGB * 100}%\n")

# fitting KNN Classifier
K = range(1, 20)
acc = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(features, y_train)
    predictionsKNN = knn.predict(features2)
    scoreKNN = accuracy_score(y_test, predictionsKNN)
    print(f"KNN Classifier score is {scoreKNN * 100}% with k = {k}")
    acc.append(scoreKNN*100)

# Elbow plot:
plt.plot(K, acc)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title("Elbow Curve without feature selection for Inter-Reseach Area")

plt.show()

# MLP / ANN
classifier = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300, activation='relu', solver='adam', random_state=1)
classifier.fit(features, y_train)
predictionsMLP = classifier.predict(features2)
scoreMLP = accuracy_score(y_test, predictionsMLP)
print(f"\nMLP Classifier score is {scoreMLP * 100}%\n")
# Out:
# Logistic Regression score is 49.42528735632184%
#
# Support Vector Classifier score is 52.87356321839081%
#
# Decision Tree Classifier score is 47.12643678160919%
#
# Random Forest Classifier score is 51.724137931034484%
#
# KNN Classifier score is 47.12643678160919% with k = 1
# KNN Classifier score is 44.827586206896555% with k = 2
# KNN Classifier score is 47.12643678160919% with k = 3
# KNN Classifier score is 47.12643678160919% with k = 4
# KNN Classifier score is 50.57471264367817% with k = 5
# KNN Classifier score is 45.97701149425287% with k = 6
# KNN Classifier score is 52.87356321839081% with k = 7
# KNN Classifier score is 51.724137931034484% with k = 8
# KNN Classifier score is 54.02298850574713% with k = 9
# KNN Classifier score is 52.87356321839081% with k = 10
# KNN Classifier score is 51.724137931034484% with k = 11
# KNN Classifier score is 51.724137931034484% with k = 12
# KNN Classifier score is 54.02298850574713% with k = 13
# KNN Classifier score is 54.02298850574713% with k = 14
# KNN Classifier score is 50.57471264367817% with k = 15
# KNN Classifier score is 48.275862068965516% with k = 16
# KNN Classifier score is 47.12643678160919% with k = 17
# KNN Classifier score is 45.97701149425287% with k = 18
# KNN Classifier score is 48.275862068965516% with k = 19
# MLP Classifier score is 47.12643678160919%

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(features, y_train).predict(features2)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))

print(classification_report(y_test,y_pred))
# Out:
# Number of mislabeled points out of a total 87 points : 48
#               precision    recall  f1-score   support
#
#            0       0.47      0.58      0.52        45
#            1       0.41      0.31      0.35        42
#
#     accuracy                           0.45        87
#    macro avg       0.44      0.44      0.44        87
# weighted avg       0.44      0.45      0.44        87

# %%
from numpy import mean
from numpy import std
# from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = GradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
# row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(features2)

print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.56      0.42        27
#            1       0.71      0.50      0.59        60
#
#     accuracy                           0.52        87
#    macro avg       0.52      0.53      0.50        87
# weighted avg       0.60      0.52      0.53        87

# %%
# histogram-based gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = HistGradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.16      0.54      0.24        13
#            1       0.86      0.49      0.62        74
#
#     accuracy                           0.49        87
#    macro avg       0.51      0.51      0.43        87
# weighted avg       0.75      0.49      0.56        87

# %%
# xgboost for classification
from numpy import asarray
from numpy import mean
from numpy import std
# from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = XGBClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = XGBClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-6eac32dd02d6> in <module>()
#      17 # fit the model on the whole dataset
#      18 model = XGBClassifier()
# ---> 19 model.fit(features, y_train)
#      20 # make a single prediction
#      21 yhat = model.predict(features2)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     424                 self.set_weight(weight)
#     425
# --> 426         self.feature_names = feature_names
#     427         self.feature_types = feature_types
#     428
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in feature_names(self, feature_names)
#     868                        not any(x in f for x in set(('[', ']', '<')))
#     869                        for f in feature_names):
# --> 870                 raise ValueError('feature_names may not contain [, ] or <')
#     871         else:
#     872             # reset feature_types also
#
# ValueError: feature_names may not contain [, ] or <

# %%
# lightgbm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = LGBMClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = LGBMClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.58      0.42        26
#            1       0.74      0.51      0.60        61
#
#     accuracy                           0.53        87
#    macro avg       0.54      0.54      0.51        87
# weighted avg       0.62      0.53      0.55        87

# %% [markdown]
# # Models lgbm

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



import warnings
warnings.filterwarnings('ignore')

# %%
features = X_train[embeded_lgb_feature]
features2 = X_test[embeded_lgb_feature]

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
X_test.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier()
# scores = cross_val_score(clf, features, y_train, cv=5)
# print(scores.mean())
clf.fit(features, y_train)
y_pred = (clf.predict(features2)>0.5).astype(int)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.52      0.39        27
#            1       0.69      0.48      0.57        60
#
#     accuracy                           0.49        87
#    macro avg       0.50      0.50      0.48        87
# weighted avg       0.57      0.49      0.51        87

# %%
from sklearn.svm import SVC

svclassifier = SVC(gamma='auto')
svclassifier.fit(features, y_train)
y_pred = svclassifier.predict(features2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.20      0.29        45
#            1       0.49      0.81      0.61        42
#
#     accuracy                           0.49        87
#    macro avg       0.51      0.50      0.45        87
# weighted avg       0.51      0.49      0.44        87

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import product
from sklearn.ensemble import VotingClassifier


clf1 = DecisionTreeClassifier()
clf2 = KNeighborsClassifier()
clf3 = SVC(kernel='rbf', probability=True)
eclf = VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)],
                        voting='soft', weights=[2, 2, 2])

clf1 = clf1.fit(features, y_train)
clf2 = clf2.fit(features, y_train)
clf3 = clf3.fit(features, y_train)
eclf = eclf.fit(features, y_train)

for clf, label in zip([clf1, clf2, clf3, eclf], ['DecisionTreeClassifier', 'KNNClassifier', 'SVC', 'voting']):
    scores = cross_val_score(clf, features, y_train, scoring='accuracy', cv=5)
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.51 (+/- 0.04) [DecisionTreeClassifier]
# Accuracy: 0.54 (+/- 0.01) [KNNClassifier]
# Accuracy: 0.59 (+/- 0.02) [SVC]
# Accuracy: 0.53 (+/- 0.04) [voting]

# %%
# fitting logistic regression
lr = LogisticRegression()
lr.fit(features, y_train)
predictionsLR = lr.predict(features2)
scoreLR = accuracy_score(y_test, predictionsLR)
print(f"Logistic Regression score is {scoreLR * 100}% \n")

# fitting SVC
svc = svm.LinearSVC()
svc.fit(features, y_train)
predictionsSVC = svc.predict(features2)
scoreSVC = accuracy_score(y_test, predictionsSVC)
print(f"Support Vector Classifier score is {scoreSVC * 100}%\n")

# fitting decision tree classifier
clf = tree.DecisionTreeClassifier()
clf.fit(features, y_train)
predictionsTree = clf.predict(features2)
scoreTree = accuracy_score(y_test, predictionsTree)
print(f"Decision Tree Classifier score is {scoreTree * 100}%\n")

# fitting Random Forest classifier
clf1 = RandomForestClassifier(max_features=23)
clf1.fit(features, y_train)
predictionsTree1 = clf1.predict(features2)
scoreTree1 = accuracy_score(y_test, predictionsTree1)
print(f"Random Forest Classifier score is {scoreTree1 * 100}%\n")

# fitting XGBoost
# xgb = XGBClassifier()
# xgb.fit(features.to_numpy(), y_train)
# predictionsXGB = xgb.predict(X_test)
# predictionsXGB = (predictionsXGB>0.5).astype(int)
# scoreXGB = accuracy_score(y_test, predictionsXGB)
# print(f"XG Boost Classifier score is {scoreXGB * 100}%\n")

# fitting KNN Classifier
K = range(1, 20)
acc = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(features, y_train)
    predictionsKNN = knn.predict(features2)
    scoreKNN = accuracy_score(y_test, predictionsKNN)
    print(f"KNN Classifier score is {scoreKNN * 100}% with k = {k}")
    acc.append(scoreKNN*100)

# Elbow plot:
plt.plot(K, acc)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.title("Elbow Curve without feature selection for Inter-Reseach Area")

plt.show()

# MLP / ANN
classifier = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300, activation='relu', solver='adam', random_state=1)
classifier.fit(features, y_train)
predictionsMLP = classifier.predict(features2)
scoreMLP = accuracy_score(y_test, predictionsMLP)
print(f"\nMLP Classifier score is {scoreMLP * 100}%\n")
# Out:
# Logistic Regression score is 56.32183908045977%
#
# Support Vector Classifier score is 55.172413793103445%
#
# Decision Tree Classifier score is 47.12643678160919%
#
# Random Forest Classifier score is 48.275862068965516%
#
# KNN Classifier score is 48.275862068965516% with k = 1
# KNN Classifier score is 49.42528735632184% with k = 2
# KNN Classifier score is 44.827586206896555% with k = 3
# KNN Classifier score is 42.5287356321839% with k = 4
# KNN Classifier score is 45.97701149425287% with k = 5
# KNN Classifier score is 42.5287356321839% with k = 6
# KNN Classifier score is 51.724137931034484% with k = 7
# KNN Classifier score is 49.42528735632184% with k = 8
# KNN Classifier score is 49.42528735632184% with k = 9
# KNN Classifier score is 51.724137931034484% with k = 10
# KNN Classifier score is 50.57471264367817% with k = 11
# KNN Classifier score is 44.827586206896555% with k = 12
# KNN Classifier score is 45.97701149425287% with k = 13
# KNN Classifier score is 48.275862068965516% with k = 14
# KNN Classifier score is 49.42528735632184% with k = 15
# KNN Classifier score is 51.724137931034484% with k = 16
# KNN Classifier score is 51.724137931034484% with k = 17
# KNN Classifier score is 51.724137931034484% with k = 18
# KNN Classifier score is 50.57471264367817% with k = 19
# MLP Classifier score is 50.57471264367817%

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(features, y_train).predict(features2)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 87 points : 44

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
# X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = GradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
# row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(features2)

print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.52      0.37        25
#            1       0.71      0.48      0.58        62
#
#     accuracy                           0.49        87
#    macro avg       0.50      0.50      0.47        87
# weighted avg       0.59      0.49      0.52        87

# %%
# histogram-based gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = HistGradientBoostingClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.60      0.37        20
#            1       0.81      0.51      0.62        67
#
#     accuracy                           0.53        87
#    macro avg       0.54      0.55      0.50        87
# weighted avg       0.68      0.53      0.57        87

# %%
# xgboost for classification
from numpy import asarray
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
# model = XGBClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = XGBClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-3e5eb772ea61> in <module>()
#      17 # fit the model on the whole dataset
#      18 model = XGBClassifier()
# ---> 19 model.fit(features, y_train)
#      20 # make a single prediction
#      21 yhat = model.predict(features2)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     424                 self.set_weight(weight)
#     425
# --> 426         self.feature_names = feature_names
#     427         self.feature_types = feature_types
#     428
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in feature_names(self, feature_names)
#     868                        not any(x in f for x in set(('[', ']', '<')))
#     869                        for f in feature_names):
# --> 870                 raise ValueError('feature_names may not contain [, ] or <')
#     871         else:
#     872             # reset feature_types also
#
# ValueError: feature_names may not contain [, ] or <

# %%
# lightgbm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
# evaluate the model
# model = LGBMClassifier()
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, features, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# fit the model on the whole dataset
model = LGBMClassifier()
model.fit(features, y_train)
# make a single prediction
yhat = model.predict(features2)
print(classification_report(yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.65      0.35        17
#            1       0.86      0.51      0.64        70
#
#     accuracy                           0.54        87
#    macro avg       0.55      0.58      0.50        87
# weighted avg       0.74      0.54      0.59        87
